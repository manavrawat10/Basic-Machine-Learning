# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot([1,2,3], [5,6,4])
plt.show()

# %%
x=[1,2,3]
y=[4,5,3]
plt.plot(x, y)
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.title("X vs Y Graph")
plt.show()
